# %%
import requests
from datetime import datetime

# %%
API_URL = "https://api.waqi.info"

# %%
token = "77d05ca5845b52922ee22f41d4386752adb7e9f5"
keyword = "Osasco, São Paulo, Brazil"
city = "osasco"

def search():   
    search_url = f"{API_URL}/v2/search/?token={token}&keyword={keyword}"
    response = requests.get(search_url)
    result = response.json()
    
    return (result)

def feed():
    search_url = f"{API_URL}/feed/osasco?token={token}"
    response = requests.get(search_url)
    result = response.json()
    
    return (result)

# %%
search()
# Out:
# {'status': 'ok',
#  'data': [{'uid': 357,
#    'aqi': '160',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Osasco, São Paulo, Brazil',
#     'geo': [-23.526721419, -46.792077661],
#     'url': 'brazil/sao-paulo/osasco'}},
#   {'uid': 352,
#    'aqi': '61',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 15:00:00',
#     'vtime': 1719943200},
#    'station': {'name': 'Marg.Tietê-Ponte dos Remédios, São Paulo, Brazil',
#     'geo': [-23.518705831, -46.743320041],
#     'url': 'brazil/sao-paulo/marg.tiete-ponte-dos-remedios'}},
#   {'uid': 3578,
#    'aqi': '1',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Cid.Universitária-USP-Ipen, São Paulo, Brazil',
#     'geo': [-23.566341776, -46.737414282],
#     'url': 'brazil/sao-paulo/cid.universitaria-usp-ipen'}},
#   {'uid': 343,
#    'aqi': '46',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Guarulhos-Paço Municipal, São Paulo, Brazil',
#     'geo': [-23.455534258, -46.518533403],
#     'url': 'brazil/sao-paulo/guarulhos-paco-municipal'}},
#   {'uid': 8516,
#    'aqi': '-',
#    'time': {'tz': '-03:00', 'stime': '1970-01-01 00:00:00', 'vtime': 0},
#    'station': {'name': 'S.José Campos-Vista Verde, São Paulo, Brazil',
#     'geo': [-23.1839218, -45.8322146],
#     'url': 'brazil/sao-paulo/s.jose-campos-vista-verde'}},
#   {'uid': 8515,
#    'aqi': '74',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'S.José Campos-Jd.Satélite, São Paulo, Brazil',
#     'geo': [-23.223645482, -45.890799996],
#     'url': 'brazil/sao-paulo/s.jose-campos-jd.satelite'}},
#   {'uid': 368,
#    'aqi': '-',
#    'time': {'tz': '-03:00', 'stime': '1970-01-01 00:00:00', 'vtime': 0},
#    'station': {'name': 'S.André-Paço Municipal, São Paulo, Brazil',
#     'geo': [-23.6569942, -46.530918756],
#     'url': 'brazil/sao-paulo/s.andre-paco-municipal'}},
#   {'uid': 375,
#    'aqi': '-',
#    'time': {'tz': '-03:00', 'stime': '1970-01-01 00:00:00', 'vtime': 0},
#    'station': {'name': 'São José dos Campos, São Paulo, Brazil',
#     'geo': [0, 0],
#     'url': 'brazil/sao-paulo/sao-jose-dos-campos'}},
#   {'uid': 341,
#    'aqi': '91',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Cubatão-Vila Parisi, São Paulo, Brazil',
#     'geo': [-23.84941617, -46.388676243],
#     'url': 'brazil/sao-paulo/cubatao-vila-parisi'}},
#   {'uid': 374,
#    'aqi': '2',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 19:00:00',
#     'vtime': 1719957600},
#    'station': {'name': 'São José do Rio Preto, São Paulo, Brazil',
#     'geo': [-20.784689284, -49.398277793],
#     'url': 'brazil/sao-paulo/sao-jose-do-rio-preto'}},
#   {'uid': 12573,
#    'aqi': '91',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Rio Claro-Jd.Guanabara, São Paulo, Brazil',
#     'geo': [-22.43904379, -47.581473311],
#     'url': 'brazil/sao-paulo/rio-claro-jd.guanabara'}},
#   {'uid': 7972,
#    'aqi': '-',
#    'time': {'tz': '-03:00',
#     'stime': '2024-03-08 23:00:00',
#     'vtime': 1709949600},
#    'station': {'name': 'S.Bernardo-Paulicéia, São Paulo, Brazil',
#     'geo': [-23.671353957, -46.584667886],
#     'url': 'brazil/sao-paulo/s.bernardo-pauliceia'}},
#   {'uid': 364,
#    'aqi': '23',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Presidente Prudente, São Paulo, Brazil',
#     'geo': [-22.119936735, -51.408777068],
#     'url': 'brazil/sao-paulo/presidente-prudente'}},
#   {'uid': 372,
#    'aqi': '53',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Santos-Ponta da Praia, São Paulo, Brazil',
#     'geo': [-23.981295157, -46.300509594],
#     'url': 'brazil/sao-paulo/santos-ponta-da-praia'}},
#   {'uid': 8513,
#    'aqi': '70',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 21:00:00',
#     'vtime': 1719964800},
#    'station': {'name': 'Guarulhos-Pimentas, São Paulo, Brazil',
#     'geo': [-23.440117008, -46.409948771],
#     'url': 'brazil/sao-paulo/guarulhos-pimentas'}},
#   {'uid': 340,
#    'aqi': '49',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Cubatão-Vale do Mogi, São Paulo, Brazil',
#     'geo': [-23.831589008, -46.369568791],
#     'url': 'brazil/sao-paulo/cubatao-vale-do-mogi'}},
#   {'uid': 8517,
#    'aqi': '35',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Campinas-Taquaral, São Paulo, Brazil',
#     'geo': [-22.874618945, -47.058972757],
#     'url': 'brazil/sao-paulo/campinas-taquaral'}},
#   {'uid': 337,
#    'aqi': '47',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 22:00:00',
#     'vtime': 1719968400},
#    'station': {'name': 'Cerqueira César, São Paulo, Brazil',
#     'geo': [-23.553542562, -46.672704769],
#     'url': 'brazil/sao-paulo/cerqueira-cesar'}},
#   {'uid': 373,
#    'aqi': '-',
#    'time': {'tz': '-03:00',
#     'stime': '2023-12-13 08:00:00',
#     'vtime': 1702465200},
#    'station': {'name': 'São Caetano do Sul, São Paulo, Brazil',
#     'geo': [-23.618442773, -46.556353938],
#     'url': 'brazil/sao-paulo/sao-caetano-do-sul'}},
#   {'uid': 333,
#    'aqi': '46',
#    'time': {'tz': '-03:00',
#     'stime': '2024-07-02 21:00:00',
#     'vtime': 1719964800},
#    'station': {'name': 'Campinas-Centro, São Paulo, Brazil',
#     'geo': [-22.902524804, -47.057210743],
#     'url': 'brazil/sao-paulo/campinas-centro'}}]}

# %%
feed()
# Out:
# {'status': 'ok',
#  'data': {'aqi': 160,
#   'idx': 357,
#   'attributions': [{'url': 'http://www.cetesb.sp.gov.br/',
#     'name': 'CETESB - Companhia Ambiental do Estado de São Paulo',
#     'logo': 'Brazil-CETESB.png'},
#    {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#   'city': {'geo': [-23.526721419, -46.792077661],
#    'name': 'Osasco, São Paulo, Brazil',
#    'url': 'https://aqicn.org/city/brazil/sao-paulo/osasco',
#    'location': ''},
#   'dominentpol': 'pm25',
#   'iaqi': {'co': {'v': 32.6},
#    'h': {'v': 83.5},
#    'no2': {'v': 60.6},
#    'p': {'v': 1027.2},
#    'pm10': {'v': 97},
#    'pm25': {'v': 160},
#    'so2': {'v': 2.6},
#    't': {'v': 16.8},
#    'w': {'v': 0.1},
#    'wg': {'v': 0.5}},
#   'time': {'s': '2024-07-02 22:00:00',
#    'tz': '-03:00',
#    'v': 1719957600,
#    'iso': '2024-07-02T22:00:00-03:00'},
#   'forecast': {'daily': {'o3': [{'avg': 1,
#       'day': '2024-06-30',
#       'max': 1,
#       'min': 1},
#      {'avg': 1, 'day': '2024-07-01', 'max': 5, 'min': 1},
#      {'avg': 2, 'day': '2024-07-02', 'max': 31, 'min': 1},
#      {'avg': 3, 'day': '2024-07-03', 'max': 23, 'min': 1},
#      {'avg': 2, 'day': '2024-07-04', 'max': 24, 'min': 1},
#      {'avg': 2, 'day': '2024-07-05', 'max': 24, 'min': 1},
#      {'avg': 3, 'day': '2024-07-06', 'max': 54, 'min': 1},
#      {'avg': 3, 'day': '2024-07-07', 'max': 42, 'min': 1}],
#     'pm10': [{'avg': 40, 'day': '2024-06-30', 'max': 40, 'min': 40},
#      {'avg': 66, 'day': '2024-07-01', 'max': 101, 'min': 39},
#      {'avg': 76, 'day': '2024-07-02', 'max': 103, 'min': 42},
#      {'avg': 71, 'day': '2024-07-03', 'max': 100, 'min': 27},
#      {'avg': 89, 'day': '2024-07-04', 'max': 133, 'min': 29},
#      {'avg': 74, 'day': '2024-07-05', 'max': 141, 'min': 24},
#      {'avg': 58, 'day': '2024-07-06', 'max': 123, 'min': 33},
#      {'avg': 64, 'day': '2024-07-07', 'max': 97, 'min': 40}],
#     'pm25': [{'avg': 69, 'day': '2024-06-30', 'max': 69, 'min': 69},
#      {'avg': 112, 'day': '2024-07-01', 'max': 177, 'min': 66},
#      {'avg': 151, 'day': '2024-07-02', 'max': 179, 'min': 85},
#      {'avg': 146, 'day': '2024-07-03', 'max': 175, 'min': 68},
#      {'avg': 164, 'day': '2024-07-04', 'max': 203, 'min': 70},
#      {'avg': 146, 'day': '2024-07-05', 'max': 220, 'min': 59},
#      {'avg': 107, 'day': '2024-07-06', 'max': 196, 'min': 51},
#      {'avg': 120, 'day': '2024-07-07', 'max': 175, 'min': 62}]}},
#   'debug': {'sync': '2024-07-03T10:19:16+09:00'}}}

# %%
import requests
import pandas as pd

def fetch_tabnet_data(disease_code, city_code):
    base_url = 'http://tabnet.datasus.gov.br/cgi/tabcgi.exe?sih/cnv/qiSP.def'
    
    # Parâmetros da requisição
    params = {
        'qtdade': 'mínima',
        'cbo02': '00',
        'cbo01': '00',
        'cbo07': '00',
        'cbo06': '71',
        'cbo05': '00',
        'cbo04': '00',
        'cbo03': '00',
        'cbo12': '02',
        'cbo11': '00',
        'cbo10': '00',
        'cbo09': '00',
        'cbo08': '00',
        'cc': "J44.9",  # Código da doença (DPOC - J44.9)
        'lc': "3550308",     # Código da cidade de São Paulo (3550308)
        'line': 'on',
        'expurgos': 'on',
        'sigla': 'SP',
        'qtdn': 'n',
        'frames': 'a',
        'f': 'd70',
    }
    
    try:
        # Faz a requisição GET
        response = requests.get(base_url, params=params, timeout=60)
        
        # Verifica se a requisição foi bem-sucedida
        if response.status_code == 200:
            # Lê o conteúdo da resposta em um DataFrame pandas
            df = pd.read_csv(response.url, sep=';', encoding='ISO-8859-1', skiprows=3, skipfooter=12, engine='python')
            
            return df
        
        else:
            print(f'Erro ao obter dados: Código {response.status_code}')
            return None
    
    except requests.exceptions.RequestException as e:
        print(f'Erro de requisição: {e}')
        return None

def main():
    disease_code = 'J44.9'  # Código para DPOC
    city_code = '3550308'   # Código IBGE da cidade de São Paulo
    
    # Chamada para obter os dados
    data = fetch_tabnet_data(disease_code, city_code)
    
    # Se os dados foram obtidos com sucesso, faça algo com eles
    if data is not None:
        print('Dados obtidos com sucesso:')
        print(data.head())  # Mostra as primeiras linhas do DataFrame
        # Aqui você pode processar os dados conforme necessário

# %%
import requests
from datetime import datetime
import json
import pandas as pd


def get_api_data():
    #end point API
    API_URL = "https://api.waqi.info"
    #token de acesso
    token = "77d05ca5845b52922ee22f41d4386752adb7e9f5"
    #chave de cidade de medicao
    keyword = "Osasco, São Paulo, Brazil"
    #cidade medicao
    city = "osasco"

    #requisicao get para dados de medicao horaria
    jsson = feed(API_URL, token, city)

    # json_object = json.loads(jsson)

    print(json.dumps(jsson, indent=2))

    # print(pd.json_normalize(jsson['pm10']))

    return jsson

def search(API_URL, token, keyword):   
    search_url = f"{API_URL}/v2/search/?token={token}&keyword={keyword}"
    response = requests.get(search_url)
    result = response.json()
    
    return (result)

def feed(API_URL, token, city):
    """
    retorna medicao horaria e previsao de AQI
    """
    search_url = f"{API_URL}/feed/{city}?token={token}"
    response = requests.get(search_url)
    result = response.json()
    
    return (result)

# %%
jsson = get_api_data()
# Out:
# {
#   "status": "ok",
#   "data": {
#     "aqi": 157,
#     "idx": 357,
#     "attributions": [
#       {
#         "url": "http://www.cetesb.sp.gov.br/",
#         "name": "CETESB - Companhia Ambiental do Estado de S\u00e3o Paulo",
#         "logo": "Brazil-CETESB.png"
#       },
#       {
#         "url": "https://waqi.info/",
#         "name": "World Air Quality Index Project"
#       }
#     ],
#     "city": {
#       "geo": [
#         -23.526721419,
#         -46.792077661
#       ],
#       "name": "Osasco, S\u00e3o Paulo, Brazil",
#       "url": "https://aqicn.org/city/brazil/sao-paulo/osasco",
#       "location": ""
#     },
#     "dominentpol": "pm25",
#     "iaqi": {
#       "co": {
#         "v": 19
#       },
#       "h": {
#         "v": 73.2
#       },
#       "no2": {
#         "v": 48.9
#       },
#       "p": {
#         "v": 1024.9
#       },
#       "pm10": {
#         "v": 97
#       },
#       "pm25": {
#         "v": 157
#       },
#       "so2": {
#         "v": 5.1
#       },
#       "t": {
#         "v": 17.7
#       },
#       "w": {
#         "v": 0.3
#       },
#       "wg": {
#         "v": 0.9
#       }
#     },
#     "time": {
#       "s": "2024-07-04 00:00:00",
#       "tz": "-03:00",
#       "v": 1720051200,
#       "iso": "2024-07-04T00:00:00-03:00"
#     },
#     "forecast": {
#       "daily": {
#         "o3": [
#           {
#             "avg": 2,
#             "day": "2024-07-02",
#             "max": 31,
#             "min": 1
#           },
#           {
#             "avg": 3,
#             "day": "2024-07-03",
#             "max": 23,
#             "min": 1
#           },
#           {
#             "avg": 2,
#             "day": "2024-07-04",
#             "max": 22,
#             "min": 1
#           },
#           {
#             "avg": 2,
#             "day": "2024-07-05",
#             "max": 24,
#             "min": 1
#           },
#           {
#             "avg": 2,
#             "day": "2024-07-06",
#             "max": 44,
#             "min": 1
#           },
#           {
#             "avg": 3,
#             "day": "2024-07-07",
#             "max": 24,
#             "min": 1
#           },
#           {
#             "avg": 2,
#             "day": "2024-07-08",
#             "max": 42,
#             "min": 1
#           }
#         ],
#         "pm10": [
#           {
#             "avg": 76,
#             "day": "2024-07-02",
#             "max": 103,
#             "min": 42
#           },
#           {
#             "avg": 70,
#             "day": "2024-07-03",
#             "max": 100,
#             "min": 27
#           },
#           {
#             "avg": 91,
#             "day": "2024-07-04",
#             "max": 149,
#             "min": 30
#           },
#           {
#             "avg": 75,
#             "day": "2024-07-05",
#             "max": 154,
#             "min": 21
#           },
#           {
#             "avg": 66,
#             "day": "2024-07-06",
#             "max": 134,
#             "min": 35
#           },
#           {
#             "avg": 49,
#             "day": "2024-07-07",
#             "max": 65,
#             "min": 16
#           },
#           {
#             "avg": 81,
#             "day": "2024-07-08",
#             "max": 156,
#             "min": 36
#           }
#         ],
#         "pm25": [
#           {
#             "avg": 151,
#             "day": "2024-07-02",
#             "max": 179,
#             "min": 86
#           },
#           {
#             "avg": 146,
#             "day": "2024-07-03",
#             "max": 175,
#             "min": 68
#           },
#           {
#             "avg": 167,
#             "day": "2024-07-04",
#             "max": 230,
#             "min": 71
#           },
#           {
#             "avg": 149,
#             "day": "2024-07-05",
#             "max": 243,
#             "min": 52
#           },
#           {
#             "avg": 115,
#             "day": "2024-07-06",
#             "max": 195,
#             "min": 52
#           },
#           {
#             "avg": 97,
#             "day": "2024-07-07",
#             "max": 146,
#             "min": 48
#           },
#           {
#             "avg": 138,
#             "day": "2024-07-08",
#             "max": 221,
#             "min": 68
#           }
#         ]
#       }
#     },
#     "debug": {
#       "sync": "2024-07-04T12:27:50+09:00"
#     }
#   }
# }

# %%
jsson.keys()
# Out:
# dict_keys(['status', 'data'])

# %%
for key in jsson.keys():
    print(key)
# Out:
# status
# data

# %%
for value in jsson.values():
    (print(value))
# Out:
# ok
# {'aqi': 157, 'idx': 357, 'attributions': [{'url': 'http://www.cetesb.sp.gov.br/', 'name': 'CETESB - Companhia Ambiental do Estado de São Paulo', 'logo': 'Brazil-CETESB.png'}, {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}], 'city': {'geo': [-23.526721419, -46.792077661], 'name': 'Osasco, São Paulo, Brazil', 'url': 'https://aqicn.org/city/brazil/sao-paulo/osasco', 'location': ''}, 'dominentpol': 'pm25', 'iaqi': {'co': {'v': 19}, 'h': {'v': 73.2}, 'no2': {'v': 48.9}, 'p': {'v': 1024.9}, 'pm10': {'v': 97}, 'pm25': {'v': 157}, 'so2': {'v': 5.1}, 't': {'v': 17.7}, 'w': {'v': 0.3}, 'wg': {'v': 0.9}}, 'time': {'s': '2024-07-04 00:00:00', 'tz': '-03:00', 'v': 1720051200, 'iso': '2024-07-04T00:00:00-03:00'}, 'forecast': {'daily': {'o3': [{'avg': 2, 'day': '2024-07-02', 'max': 31, 'min': 1}, {'avg': 3, 'day': '2024-07-03', 'max': 23, 'min': 1}, {'avg': 2, 'day': '2024-07-04', 'max': 22, 'min': 1}, {'avg': 2, 'day': '2024-07-05', 'max': 24, 'min': 1}, {'avg': 2, 'day': '2024-07-06', 'max': 44, 'min': 1}, {'avg': 3, 'day': '2024-07-07', 'max': 24, 'min': 1}, {'avg': 2, 'day': '2024-07-08', 'max': 42, 'min': 1}], 'pm10': [{'avg': 76, 'day': '2024-07-02', 'max': 103, 'min': 42}, {'avg': 70, 'day': '2024-07-03', 'max': 100, 'min': 27}, {'avg': 91, 'day': '2024-07-04', 'max': 149, 'min': 30}, {'avg': 75, 'day': '2024-07-05', 'max': 154, 'min': 21}, {'avg': 66, 'day': '2024-07-06', 'max': 134, 'min': 35}, {'avg': 49, 'day': '2024-07-07', 'max': 65, 'min': 16}, {'avg': 81, 'day': '2024-07-08', 'max': 156, 'min': 36}], 'pm25': [{'avg': 151, 'day': '2024-07-02', 'max': 179, 'min': 86}, {'avg': 146, 'day': '2024-07-03', 'max': 175, 'min': 68}, {'avg': 167, 'day': '2024-07-04', 'max': 230, 'min': 71}, {'avg': 149, 'day': '2024-07-05', 'max': 243, 'min': 52}, {'avg': 115, 'day': '2024-07-06', 'max': 195, 'min': 52}, {'avg': 97, 'day': '2024-07-07', 'max': 146, 'min': 48}, {'avg': 138, 'day': '2024-07-08', 'max': 221, 'min': 68}]}}, 'debug': {'sync': '2024-07-04T12:27:50+09:00'}}

# %%
jsson['data']['iaqi']
# Out:
# {'co': {'v': 19},
#  'h': {'v': 73.2},
#  'no2': {'v': 48.9},
#  'p': {'v': 1024.9},
#  'pm10': {'v': 97},
#  'pm25': {'v': 157},
#  'so2': {'v': 5.1},
#  't': {'v': 17.7},
#  'w': {'v': 0.3},
#  'wg': {'v': 0.9}}

# %%
jsson['data']['time']
# Out:
# {'s': '2024-07-04 00:00:00',
#  'tz': '-03:00',
#  'v': 1720051200,
#  'iso': '2024-07-04T00:00:00-03:00'}

# %%
jsson['data']['forecast']
# Out:
# {'daily': {'o3': [{'avg': 2, 'day': '2024-07-02', 'max': 31, 'min': 1},
#    {'avg': 3, 'day': '2024-07-03', 'max': 23, 'min': 1},
#    {'avg': 2, 'day': '2024-07-04', 'max': 22, 'min': 1},
#    {'avg': 2, 'day': '2024-07-05', 'max': 24, 'min': 1},
#    {'avg': 2, 'day': '2024-07-06', 'max': 44, 'min': 1},
#    {'avg': 3, 'day': '2024-07-07', 'max': 24, 'min': 1},
#    {'avg': 2, 'day': '2024-07-08', 'max': 42, 'min': 1}],
#   'pm10': [{'avg': 76, 'day': '2024-07-02', 'max': 103, 'min': 42},
#    {'avg': 70, 'day': '2024-07-03', 'max': 100, 'min': 27},
#    {'avg': 91, 'day': '2024-07-04', 'max': 149, 'min': 30},
#    {'avg': 75, 'day': '2024-07-05', 'max': 154, 'min': 21},
#    {'avg': 66, 'day': '2024-07-06', 'max': 134, 'min': 35},
#    {'avg': 49, 'day': '2024-07-07', 'max': 65, 'min': 16},
#    {'avg': 81, 'day': '2024-07-08', 'max': 156, 'min': 36}],
#   'pm25': [{'avg': 151, 'day': '2024-07-02', 'max': 179, 'min': 86},
#    {'avg': 146, 'day': '2024-07-03', 'max': 175, 'min': 68},
#    {'avg': 167, 'day': '2024-07-04', 'max': 230, 'min': 71},
#    {'avg': 149, 'day': '2024-07-05', 'max': 243, 'min': 52},
#    {'avg': 115, 'day': '2024-07-06', 'max': 195, 'min': 52},
#    {'avg': 97, 'day': '2024-07-07', 'max': 146, 'min': 48},
#    {'avg': 138, 'day': '2024-07-08', 'max': 221, 'min': 68}]}}
